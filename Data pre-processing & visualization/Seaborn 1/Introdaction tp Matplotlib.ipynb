# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,3,2,67,8,433,-9])

# %%
x = [2,6,3,88,1,0,2,45,57,-78,9,]
y = sorted(x)
print(y)
plt.plot(x,y)
# Out:
# [-78, 0, 1, 2, 2, 3, 6, 9, 45, 57, 88]
